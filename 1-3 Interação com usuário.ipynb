# %% [markdown]
# # Visualização de Variáveis e Textos

# %%
print('conhecendo o comando Print')

x = 8
print(x)
# Out:
# conhecendo o comando Print
# 8

# %%
 y=10
 soma = x + y
 print(soma)
# Out:
# 18

# %%
 nome = 'Rodrigo Rebouças'
 print(nome)
# Out:
# Rodrigo Rebouças

# %% [markdown]
# Concatenação

# %%
x = 5
print('o valor de x é', x)
# Out:
# o valor de x é 5

# %%
print('o valor de x é', x, 'e o dobro é', x*2)
# Out:
# o valor de x é 5 e o dobro é 10

# %%
print('Eu,', nome, 'tirei', x, 'na prova de Python')
# Out:
# Eu, Rodrigo Rebouças tirei 5 na prova de Python

# %%
y = 10; z = 20 + x - y
print('Declarar variáveis na mesma linha:', y, z)
# Out:
# Declarar variáveis na mesma linha: 10 15

# %% [markdown]
# Type

# %%
x = 10
type(x)
print('x', type(x))

nome= 'Larissa'
print('nome', type(nome))

num = '100'
num_convert = int(num)   #converter variável
print('num', type(num))
print('num_convert', type(num_convert))

num_float= float(num)
print('num_float', num_float)
# Out:
# x <class 'int'>
# nome <class 'str'>
# num <class 'str'>
# num_convert <class 'int'>
# num_float 100.0

# %% [markdown]
# Input
#
# * Armazenar a informação digitada pelo usuário em uma variável
# * O dado armazenado sempre será um texto

# %%
nome = input("Digite o nome de usuário")  # Aguarda o usuário digital algo
print(nome)
# Out:
# Digite o nome de usuário Larissa
#  Larissa

# %%
valor = input('Digite a nota ')
print(nome, 'sua nota foi', valor)
# Out:
# Digite a nota 7
#  Larissa sua nota foi 7

# %%
valor = input('Digite o valor do produto: ')
print(valor)
# Out:
# Digite o valor do produto: 100
# 100

# %%
desconto = valor - 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-2e29d7dd191a> in <cell line: 1>()
# ----> 1 desconto = valor - 5
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
valor_convert = int(valor)
desconto = valor_convert - 5
print(desconto)
# Out:
# 95

# %%
desconto = int(valor) - 5
print(desconto)
# Out:
# 95
